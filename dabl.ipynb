# %%
import dabl
import matplotlib.pyplot as plt

# data = dabl.datasets.load_ames()
data = dabl.datasets.load_titanic()

data.head()
# data.describe()
# dabl.plot(data, 'SalePrice')
# plt.show()

dabl.plot(data, 'survived')
# Out:
# d:\python\python311\Lib\site-packages\dabl\plot\supervised.py:610: FutureWarning: The second positional argument of plot is a Series 'y'. If passing a column name, use a keyword.
#   warnings.warn("The second positional argument of plot is a Series 'y'."
# Target looks like classification
# Linear Discriminant Analysis training set score: 0.578
# [[<Figure size 1500x1500 with 30 Axes>,
#   <Figure size 1600x400 with 4 Axes>,
#   <Figure size 640x480 with 1 Axes>],
#  None]
